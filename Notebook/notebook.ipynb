# %% [markdown]
# ## Let's understand the Total loss

# %%
kl_weight = 0.000000000001
raw_kl = 37,933.0
rec_loss = 0.0031 
perc_loss = 0.0437

total_loss = (kl_weight * raw_kl) + rec_loss + perc_loss 
total_loss
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 rec_loss = 0.0031
#       4 perc_loss = 0.0437
# ----> 6 total_loss = (kl_weight * raw_kl)
#       7 total_loss
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
1e-12
# Out:
# 1e-12

# %%
import torch 
from torch import nn 

# shape of input Tensor: torch.Size([1, 128, 6, 382, 638])
conv_network = nn.Conv3d(in_channels=128,
                         out_channels=128,
                         kernel_size=3)

x = torch.randn(1, 128, 6, 382, 638)
out = conv_network(x)
out.shape
# Out:
# torch.Size([1, 128, 4, 380, 636])
